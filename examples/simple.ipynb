# %%
import numpy as np
import cloudglancer as cg

# %%
# Generate random 3D points
points = np.random.randn(500, 3)

# Create and display the plot
fig = cg.plot(points, title="Point Cloud", size=1.0)
fig.show()
